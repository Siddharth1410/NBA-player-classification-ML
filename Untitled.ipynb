# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# %%
nba = pd.read_csv('NBAstats.csv')
original_headers = list(nba.columns.values)
feature_columns = ['Age', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', \
    '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', \
    'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PS/G','Pos']
training_dataframe=nba[feature_columns]
cols=27
counter_dict=Counter(nba['Pos'])
for x in c:
    counter_dict[x]=float(counter_dict[x]/475)

# %%
# Out:
#              Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...    FT%  \
# 0        Quincy Acy  PF   25  SAC  59  29  14.8  2.0   3.6  0.556  ...  0.735
# 1      Jordan Adams  SG   21  MEM   2   0   7.5  1.0   3.0  0.333  ...  0.600
# 2      Steven Adams   C   22  OKC  80  80  25.2  3.3   5.3  0.613  ...  0.582
# 3     Arron Afflalo  SG   30  NYK  71  57  33.4  5.0  11.3  0.443  ...  0.840
# 4     Alexis Ajinca   C   27  NOP  59  17  14.6  2.5   5.3  0.476  ...  0.839
# ..              ...  ..  ...  ...  ..  ..   ...  ...   ...    ...  ...    ...
# 470       Joe Young  PG   23  IND  41   0   9.4  1.5   4.1  0.367  ...  0.800
# 471      Nick Young  SG   30  LAL  54   2  19.1  2.3   6.9  0.339  ...  0.829
# 472  Thaddeus Young  PF   27  BRK  73  73  33.0  6.8  13.2  0.514  ...  0.644
# 473     Cody Zeller   C   23  CHO  73  60  24.3  3.2   6.0  0.529  ...  0.754
# 474    Tyler Zeller   C   26  BOS  60   3  11.8  2.3   4.8  0.476  ...  0.815
#
#      ORB  DRB  TRB  AST  STL  BLK  TOV   PF  PS/G
# 0    1.1  2.1  3.2  0.5  0.5  0.4  0.5  1.7   5.2
# 1    0.0  1.0  1.0  1.5  1.5  0.0  1.0  1.0   3.5
# 2    2.7  3.9  6.7  0.8  0.5  1.1  1.1  2.8   8.0
# 3    0.3  3.4  3.7  2.0  0.4  0.1  1.2  2.0  12.8
# 4    1.3  3.3  4.6  0.5  0.3  0.6  0.9  2.3   6.0
# ..   ...  ...  ...  ...  ...  ...  ...  ...   ...
# 470  0.1  1.1  1.2  1.6  0.4  0.0  0.8  0.7   3.8
# 471  0.3  1.5  1.8  0.6  0.4  0.1  0.6  0.9   7.3
# 472  2.4  6.6  9.0  1.8  1.5  0.5  1.9  2.5  15.1
# 473  1.9  4.3  6.2  1.0  0.8  0.9  0.9  2.8   8.7
# 474  1.0  1.9  3.0  0.5  0.2  0.4  0.8  1.6   6.1
#
# [475 rows x 29 columns]

# %%
training_dataframe[training_dataframe['Pos']=='C']
# Out:
#      Age   G  GS    MP   FG   FGA    FG%   3P  3PA    3P%  ...  ORB  DRB  \
# 2     22  80  80  25.2  3.3   5.3  0.613  0.0  0.0  0.000  ...  2.7  3.9
# 4     27  59  17  14.6  2.5   5.3  0.476  0.0  0.0  0.000  ...  1.3  3.3
# 5     27  60   5  13.3  2.2   3.8  0.596  0.0  0.0  0.000  ...  1.4  3.4
# 12    37  27  15  14.9  1.4   2.7  0.528  0.1  0.5  0.286  ...  1.3  2.3
# 21    33  19   0   5.1  0.3   0.5  0.600  0.0  0.0  0.000  ...  0.4  0.7
# ..   ...  ..  ..   ...  ...   ...    ...  ...  ...    ...  ...  ...  ...
# 440   25  65  60  31.3  8.2  16.1  0.510  0.0  0.1  0.222  ...  2.7  6.2
# 451   26  73  43  29.1  5.7   9.3  0.606  0.0  0.0  0.000  ...  3.3  8.6
# 463   25  51  10  12.9  1.7   3.2  0.537  0.0  0.0  0.000  ...  1.1  2.3
# 473   23  73  60  24.3  3.2   6.0  0.529  0.0  0.1  0.100  ...  1.9  4.3
# 474   26  60   3  11.8  2.3   4.8  0.476  0.0  0.0  0.000  ...  1.0  1.9
#
#       TRB  AST  STL  BLK  TOV   PF  PS/G  Pos
# 2     6.7  0.8  0.5  1.1  1.1  2.8   8.0    C
# 4     4.6  0.5  0.3  0.6  0.9  2.3   6.0    C
# 5     4.8  0.8  0.8  1.1  1.1  2.3   5.5    C
# 12    3.6  0.4  0.6  0.5  0.3  1.1   3.9    C
# 21    1.1  0.1  0.1  0.6  0.1  0.8   0.9    C
# ..    ...  ...  ...  ...  ...  ...   ...  ...
# 440   8.9  2.8  0.8  1.1  1.9  2.7  18.2    C
# 451  11.8  0.4  0.6  3.7  1.9  2.8  14.2    C
# 463   3.4  0.4  0.4  1.0  0.5  1.5   4.3    C
# 473   6.2  1.0  0.8  0.9  0.9  2.8   8.7    C
# 474   3.0  0.5  0.2  0.4  0.8  1.6   6.1    C
#
# [89 rows x 27 columns]

# %%
list_of_means = []
list_of_std = []
#print(counter_dict)
for x in sorted(counter_dict.keys()):
    df1=training_dataframe[training_dataframe['Pos']==x]
    mean_series = df1.mean()
    std_series = df1.std()
    list_of_means.append(mean_series.values)
    list_of_std.append(std_series.values)
df_means=pd.DataFrame(list_of_means,columns=col_vec)
df_std=pd.DataFrame(list_of_std,columns=col_vec)
df_std=df_std.where(df_std>=0.01,0.01)
df_std[cols]=df_means[cols]
df_row,df_col=df_std.shape
#ss=df_means[df_means[9]==float(2)][1].tolist()

#print(ss[0])
for i in range(df_row):
    for j in range(1,df_col):
        pass
        print('Class =%d'%df_means.iloc[i][cols],'Attribute =%d'%j,"mean = %.2f" % df_means.iloc[i][j],"std = %0.2f"%df_std.iloc[i][j])
#df_std
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-362e0a389a51> in <module>
#       8     list_of_means.append(mean_series.values)
#       9     list_of_std.append(std_series.values)
# ---> 10 df_means=pd.DataFrame(list_of_means,columns=col_vec)
#      11 df_std=pd.DataFrame(list_of_std,columns=col_vec)
#      12 df_std=df_std.where(df_std>=0.01,0.01)
#
# NameError: name 'col_vec' is not defined
